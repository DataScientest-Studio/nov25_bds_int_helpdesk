# %%
# import libraries
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
# Load the 'issues.csv' dataset
dfi = pd.read_csv('issues.csv')

# Display the first few rows of the dataset
dfi.head()
# Out:
#         id                    started                      ended  issue_num  \
# 0  11887.0  2016-01-06 08:23:43+00:00  2016-01-06 08:56:55+00:00      186.0
# 1  11890.0  2016-01-11 10:06:19+00:00  2016-01-12 12:30:23+00:00      190.0
# 2  11904.0  2016-01-21 07:28:20+00:00  2016-01-26 08:21:47+00:00      198.0
# 3  11907.0  2016-01-26 07:44:54+00:00  2016-01-26 07:45:48+00:00      209.0
# 4  11912.0  2016-02-01 13:45:47+00:00  2016-02-07 06:21:42+00:00      217.0
#
#   issue_proj issue_reporter issue_assignee  issue_contr_count issue_type  \
# 0       d1z0           4olg            NaN                1.0     Ticket
# 1       d1z0           4olg            NaN                1.0     Ticket
# 2       d1z0           4ohk           4ohk                1.0     Ticket
# 3       d1z0           4olg            NaN                1.0   Vacation
# 4       d1z0           4ohk           4ohk                1.0      Story
#
#   issue_priority  ... wf_cancelled wfe_cancelled wf_under_review  \
# ...

# %%
#dfi.dtypes
dfi['started'] = pd.to_datetime(dfi['started'], format='ISO8601')
dfi['ended'] = pd.to_datetime(dfi['ended'], format='ISO8601')
dfi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66691 entries, 0 to 66690
# Data columns (total 58 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   id                             66691 non-null  float64
#  1   started                        66691 non-null  datetime64[ns, UTC]
#  2   ended                          66691 non-null  datetime64[ns, UTC]
#  3   issue_num                      66691 non-null  float64
#  4   issue_proj                     66691 non-null  object
#  5   issue_reporter                 66691 non-null  object
#  6   issue_assignee                 35644 non-null  object
#  7   issue_contr_count              66691 non-null  float64
#  8   issue_type                     66691 non-null  object
#  9   issue_priority                 66691 non-null  object
#  10  issue_created                  66691 non-null  object
#  11  issue_resolution_date          65838 non-null  object
# ...

# %%
# Load the 'issues.csv' dataset
dfis = pd.read_csv('issues_snapshot.csv')

# Display the first few rows of the dataset
dfis.head()
# Out:
#    idx       id                    started                      ended  \
# 0    0  11887.0  2016-01-06 08:23:43+00:00  2016-01-06 08:56:55+00:00
# 1    1  11890.0  2016-01-11 10:06:19+00:00  2016-01-12 12:30:23+00:00
# 2    2  11904.0  2016-01-21 07:28:20+00:00  2016-01-26 08:21:47+00:00
# 3    3  11907.0  2016-01-26 07:44:54+00:00  2016-01-26 07:45:48+00:00
# 4    4  11912.0  2016-02-01 13:45:47+00:00  2016-02-07 06:21:42+00:00
#
#    issue_num issue_proj issue_reporter issue_assignee  issue_contr_count  \
# 0      186.0       d1z0           4olg            NaN                1.0
# 1      190.0       d1z0           4olg            NaN                1.0
# 2      198.0       d1z0           4ohk           4ohk                1.0
# 3      209.0       d1z0           4olg            NaN                1.0
# 4      217.0       d1z0           4ohk           4ohk                1.0
#
#   issue_type  ... wfe_cancelled wf_under_review wfe_under_review wf_approved  \
# ...

# %%
dfis['started'] = pd.to_datetime(dfis['started'], format='ISO8601')
dfis['ended'] = pd.to_datetime(dfis['ended'], format='ISO8601')
dfis.info()
dfis.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90963 entries, 0 to 90962
# Data columns (total 60 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   idx                            90963 non-null  int64
#  1   id                             90963 non-null  float64
#  2   started                        90963 non-null  datetime64[ns, UTC]
#  3   ended                          90963 non-null  datetime64[ns, UTC]
#  4   issue_num                      90963 non-null  float64
#  5   issue_proj                     90963 non-null  object
#  6   issue_reporter                 90963 non-null  object
#  7   issue_assignee                 59916 non-null  object
#  8   issue_contr_count              90963 non-null  float64
#  9   issue_type                     90963 non-null  object
#  10  issue_priority                 90963 non-null  object
#  11  issue_created                  90963 non-null  object
# ...

# %%
# Load the 'issues_change_history.csv' dataset
dfich = pd.read_csv('issues_change_history.csv')

# Display the first few rows of the dataset
dfich.head()
# Out:
#         id     issueid   field        value                    created  \
# 0  10810.0  47751000.0  status     resolved  2016-03-24 15:35:53+00:00
# 1  10821.0  47751000.0  status     resolved  2016-03-24 16:12:16+00:00
# 2  10823.0  47751000.0  status     reopened  2016-03-24 16:12:19+00:00
# 3  10824.0  47751000.0  status  in_progress  2016-03-24 16:12:22+00:00
# 4  10825.0  47751000.0  status     resolved  2016-03-24 16:13:49+00:00
#
#    change_group_id
# 0          10707.0
# 1          10715.0
# 2          10716.0
# 3          10717.0
# 4          10718.0

# %%
dfich.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 257508 entries, 0 to 257507
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   id               257508 non-null  float64
#  1   issueid          257508 non-null  float64
#  2   field            257508 non-null  object
#  3   value            255668 non-null  object
#  4   created          257508 non-null  object
#  5   change_group_id  257508 non-null  float64
# dtypes: float64(3), object(3)
# memory usage: 11.8+ MB

# %%
# Load the 'sample_utterances.csv' dataset
dfsu = pd.read_csv('sample_utterances.csv')

# Display the first few rows of the dataset
dfsu.head()
# Out:
#      issueid           id  comment_seq  utr_seq      author  \
# 0  1004298.0  211718014.0            0        0  .wy0w13yhr
# 1  1004298.0  211718014.0            0        1  .wy0w13yhr
# 2  1004298.0  211718014.0            0        2  .wy0w13yhr
# 3  1004298.0    1045407.0            1        0       z2w_x
# 4  1004298.0    1045407.0            1        1       z2w_x
#
#                      created  is_private  \
# 0  2022-01-02 11:12:51+00:00         0.0
# 1  2022-01-02 11:12:51+00:00         0.0
# 2  2022-01-02 11:12:51+00:00         0.0
# 3  2022-01-02 11:13:02+00:00         1.0
# 4  2022-01-02 11:13:02+00:00         1.0
#
#                                           actionbody author_role
# 0                                  dear ph_name team    reporter
# 1  we need your urgent support to fix list of vul...    reporter
# 2  please provide resolution date before end of ‘...    reporter
# 3                                                  .      others
# ...

# %%
#dfis['issue_type'].unique()
dfis['issue_type'].value_counts()
# Out:
# issue_type
# Ticket            63200
# Service            8384
# Story              4841
# Subtask            4792
# HD Service         3298
# Task               2071
# Project            1388
# Vacation            869
# Sub-task            559
# Deployment          507
# Epic                406
# Retrospective       257
# Sprint Summary      221
# Assistance          116
# Bug                  54
# Name: count, dtype: int64

# %%
groupby_m = dfis.groupby([pd.Grouper(key = 'started', freq = 'm'), 
                               dfis['issue_type']])\
                     .agg({'id':'count'}).unstack().fillna(0)

groupby_m.plot(figsize = (20, 4.5), style = 'o-').legend(loc='upper left', fontsize=12);
# Out:
# /var/folders/5p/fgg9702s3x98f2q9vbz1xfm40000gx/T/ipykernel_66489/1462262307.py:1: FutureWarning: 'm' is deprecated and will be removed in a future version, please use 'ME' instead.
#   groupby_m = dfis.groupby([pd.Grouper(key = 'started', freq = 'm'),

# %%
groupby_m_time = dfis.groupby([pd.Grouper(key = 'started', freq = 'm'), 
                               dfis['issue_type']])\
                     .agg({'wf_total_time':'mean'}).unstack().fillna(0)

groupby_m_time.plot(figsize = (20, 4.5), style = 'o-').legend(loc='upper left', fontsize=12);
# Out:
# /var/folders/5p/fgg9702s3x98f2q9vbz1xfm40000gx/T/ipykernel_66489/1286649556.py:1: FutureWarning: 'm' is deprecated and will be removed in a future version, please use 'ME' instead.
#   groupby_m_time = dfis.groupby([pd.Grouper(key = 'started', freq = 'm'),
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %%
issues = pd.crosstab(dfis['issue_type'], dfis['target'], normalize = "index")
print(gender)
print(f"{gender.loc['Female'][1]:.2%} of female patients are sick and {gender.loc['Male'][1]:.2%} of male patients are sick.")
target       0.0       1.0
