# %% [markdown]
# # 1. Import Libraries

# %%
import os
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import openpyxl
import seaborn as sns
import re

# %% [markdown]
# # 2. Load Data

# %%
directory = Path("../data/raw/Help Desk Tickets")

dfi    = pd.read_csv(directory    / "issues.csv",                low_memory = False)
dfs    = pd.read_csv(directory    / "issues_snapshot.csv",       low_memory = False)
dfch   = pd.read_csv(directory    / "issues_change_history.csv", low_memory = False)
dfu    = pd.read_csv(directory    / "sample_utterances.csv",     low_memory = False)
dfrate = pd.read_excel(directory  / "issues_snapshot_sample.xlsx")

datasets = {"Issues"         : dfi,
            "Snapshot"       : dfs,
            "Change History" : dfch,
            "Utterances"     : dfu,
            "Rated Sample"   : dfrate}

# %% [markdown]
# # 3. Overview over Datasets

# %%
for name, df in datasets.items():
    print(
        f"{name.upper()}\n\n"
        f"Columns: {df.shape[1]}\n"
        f"Rows: {df.shape[0]}\n\n"
        f"Variables: {", ".join(df.columns)}\n")
    display(df.head(3))
    print("\n\n")
# Out:
# ISSUES
#
# Columns: 58
# Rows: 66691
#
# Variables: id, started, ended, issue_num, issue_proj, issue_reporter, issue_assignee, issue_contr_count, issue_type, issue_priority, issue_created, issue_resolution_date, issue_resolution, issue_status, issue_comments_count, last_change_date, wf_in_review, wfe_in_review, wf_deployment, wfe_deployment, wf_resolved, wfe_resolved, wf_open, wfe_open, wf_monitoring, wfe_monitoring, wf_done, wfe_done, wf_pending_customer_approval, wfe_pending_customer_approval, wf_rejected, wfe_rejected, wf_testing_monitoring, wfe_testing_monitoring, wf_in_progress, wfe_in_progress, wf_reopened, wfe_reopened, wf_to_do, wfe_to_do, wf_validation, wfe_validation, wf_resolved_under_monitoring, wfe_resolved_under_monitoring, wf_closed, wfe_closed, wf_waiting, wfe_waiting, wf_cancelled, wfe_cancelled, wf_under_review, wfe_under_review, wf_approved, wfe_approved, wf_pending_deployment, wfe_pending_deployment, wf_total_time, processing_steps
# ...

# %% [markdown]
# The **Issues** and **Snapshot** datasets describe largely the same tickets, but at different levels of detail:
#
# * **Issues** provides a **ticket-level summary**: one row per issue, capturing the **final workflow status** and key dates that reflect the ticket’s overall history.
# * **Snapshot** provides a **step-by-step view**: it breaks the same tickets into **multiple rows**, with **one row per workflow step**, showing how each issue moved through the process over time.

# %% [markdown]
# # 4. Data Types

# %%
def dtype_col(df):
    dtype_to_col = {}

    for variable, dtype in df.dtypes.items():
        dtype_str = str(dtype)

        if dtype_str not in dtype_to_col:
            dtype_to_col[dtype_str] = []

        dtype_to_col[dtype_str].append(variable)

    return pd.DataFrame({dtype: pd.Series(vars_) for dtype, vars_ in dtype_to_col.items()})


id_columns = ["id", "issueid", "idx"]

for dataset_name, df in datasets.items():
    convert_col = [c for c in id_columns if c in df.columns]
    df[convert_col] = df[convert_col].astype("object")
    

for name, df in datasets.items():
    print(f"\n{name.upper()}")
    display(dtype_col(df).style.format(na_rep = ""))  # keep NaN out of tables
# Out:
# ISSUES
# <style type="text/css">
# </style>
# <table id="T_d19fd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d19fd_level0_col0" class="col_heading level0 col0" >object</th>
#       <th id="T_d19fd_level0_col1" class="col_heading level0 col1" >float64</th>
#       <th id="T_d19fd_level0_col2" class="col_heading level0 col2" >int64</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d19fd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d19fd_row0_col0" class="data row0 col0" >id</td>
#       <td id="T_d19fd_row0_col1" class="data row0 col1" >issue_num</td>
#       <td id="T_d19fd_row0_col2" class="data row0 col2" >issue_comments_count</td>
#     </tr>
#     <tr>
#       <th id="T_d19fd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d19fd_row1_col0" class="data row1 col0" >started</td>
#       <td id="T_d19fd_row1_col1" class="data row1 col1" >issue_contr_count</td>
# ...

# %% [markdown]
# # 5. Numeric Variables

# %%
dfi_num = dfi.select_dtypes(include = "number").copy()                         # as dataframe
dfi_num = dfi_num.loc[:, ~dfi_num.columns.str.startswith(("wfe_", "issue_"))]  # excludes the accumulated workflow steps a ticket has passed

num_col = dfi_num.columns.tolist()                                             # as list

# more readable version
num_var_read = {'issue_contr_count'            : "Number of Assignees", 
                'issue_comments_count'         : "Number of Comments", 
                'wf_in_review'                 : "Status - In Review", 
                'wf_deployment'                : "Status - Deployment", 
                'wf_resolved'                  : "Status - Resolved", 
                'wf_open'                      : "Status - Open", 
                'wf_monitoring'                : "Status - Monitoring", 
                'wf_done'                      : "Status - Done", 
                'wf_pending_customer_approval' : "Status - Pending: Customer Approval", 
                'wf_rejected'                  : "Status - Rejected", 
                'wf_testing_monitoring'        : "Status - Testing Monitoring", 
                'wf_in_progress'               : "Status - In Progress", 
                'wf_reopened'                  : "Status - Reopened", 
                'wf_to_do'                     : "Status - To Do", 
                'wf_validation'                : "Status - Validation", 
                'wf_resolved_under_monitoring' : "Status - Resolved under Monitoring", 
                'wf_closed'                    : "Status - Closed", 
                'wf_waiting'                   : "Status - Waiting", 
                'wf_cancelled'                 : "Status - Cancelled", 
                'wf_under_review'              : "Status - Under Review", 
                'wf_approved'                  : "Status - Approved", 
                'wf_pending_deployment'        : "Status - Pending: Deployment", 
                'wf_total_time'                : "Total Time", 
                'processing_steps'             : "Processing Steps until Final"}

# %% [markdown]
# # 6. Categorical and Dummy Variables

# %%
dfi_cat = ["issue_type", 
           "issue_priority", 
           "issue_resolution", 
           "issue_status", 
           "country_code"]

cat_col = [c for c in dfi_cat if c in dfi.columns]

# more readable version
cat_var_read = {'issue_type'            : "Type (Issue)", 
                'issue_priority'        : "Priority (Issue)", 
                'issue_resolution'      : "Resolution Category", 
                'issue_status'          : "Last Status", 
                'country_code'          : "Country Code"}


all_col = dfi[num_col + cat_col].copy()

dummy_col = pd.get_dummies(all_col,
                           columns = cat_col,
                           drop_first = True,    # avoids multicollinearity (category becomes reference)
                           dtype = int)          # 0/1 instead of True/False

# %% [markdown]
# # 7. Duplicates in Datasets

# %%
for name, df in datasets.items():
    print(
        f"{name.title()}:",
        df.duplicated().sum())
# Out:
# Issues: 0
# Snapshot: 0
# Change History: 0
# Utterances: 0
# Rated Sample: 0

# %% [markdown]
# There are no duplicates in the datasets.

# %% [markdown]
# # 8. Uniqueness of IDs

# %%
print("Issues:",   dfi.duplicated(["id"]).sum(), "duplicate rows when using ID as the ticket identifier.")
print("Snapshot:", dfs.duplicated(["id"]).sum(), "rows that share the same ID (same ticket appears multiple times).")
print("Change:",   dfch.duplicated(["issueid", "change_group_id"]).sum(), "rows that share the same Issue-ID & Change-Group-ID update event.")
# Out:
# Issues: 0 duplicate rows when using ID as the ticket identifier.
# Snapshot: 24272 rows that share the same ID (same ticket appears multiple times).
# Change: 6 rows that share the same Issue-ID & Change-Group-ID update event.

# %% [markdown]
# # 9. Missingness

# %% [markdown]
# ## a. Missingness of Entries (Table)

# %%
def missingness(name, df):
    miss = (df.isna().mean() * 100).sort_values(ascending = False).round(2) # amount of missing values in percent
    miss = miss[~miss.index.str.startswith(("wf_", "wfe_"))]                # except for workflow variables
    print(f"Percentage of Missing Entries in: {name.title()}")              # title
    display(miss.to_frame("%"))                                             # table


for name, df in datasets.items():
    missingness(name, df)
# Out:
# Percentage of Missing Entries in: Issues
#                            %
# issue_assignee         46.55
# issue_resolution        1.28
# issue_resolution_date   1.28
# last_change_date        0.00
# id                      0.00
# issue_status            0.00
# ended                   0.00
# issue_num               0.00
# issue_proj              0.00
# issue_reporter          0.00
# issue_contr_count       0.00
# issue_type              0.00
# issue_priority          0.00
# issue_created           0.00
# issue_comments_count    0.00
# started                 0.00
# processing_steps        0.00
# Percentage of Missing Entries in: Snapshot
#                            %
# issue_assignee         34.13
# issue_resolution_date   1.59
# issue_resolution        1.59
# last_change_date        0.00
# idx                     0.00
# turn                    0.00
# started                 0.00
# ended                   0.00
# issue_num               0.00
# issue_proj              0.00
# ...

# %% [markdown]
# ## b. Missingness of Entries (Plot)

# %%
def missingness_plot(name, df):
    miss = (df.isna().mean() * 100).sort_values(ascending = False) # amount of missing values in percent
    miss = miss[~miss.index.str.startswith(("wf_", "wfe_"))]       # except for workflow variables

    x = np.arange(1, len(miss) + 1)
    y = miss.values

    complete = (y == 0)                                            # 0% missing
    missing = ~complete                                            # >0% missing (everything that is not complete)

    plt.figure()
    plt.plot(x, y, color = "tab:grey", linewidth = "0.5")
    
    plt.scatter(x[missing],  y[missing],  color = "tab:red",  marker = ".")
    plt.scatter(x[complete], y[complete], color = "tab:blue", marker = ".")

    plt.xticks(x, miss.index, rotation = 90)
    plt.xlabel("Variables")
    plt.ylabel("Percentage of Missingness")
    plt.title(f"Missingness in Variables in: {name.title()}")
    plt.tight_layout()
    plt.show()

    print("Note: Red points indicate some extent of missingness. Variables for workflow steps are excluded.\n\n")

for name, df in datasets.items():
    missingness_plot(name, df)
# Out:
# Note: Red points indicate some extent of missingness. Variables for workflow steps are excluded.
# Note: Red points indicate some extent of missingness. Variables for workflow steps are excluded.
# Note: Red points indicate some extent of missingness. Variables for workflow steps are excluded.
# Note: Red points indicate some extent of missingness. Variables for workflow steps are excluded.
# Note: Red points indicate some extent of missingness. Variables for workflow steps are excluded.

# %% [markdown]
# #### Take-away:
# 1. **Issues (main ticket table)**
#    Most fields are complete. Only a very small share of tickets (under 1%) is missing information about the **resolution category/date** or the **last change date**. In contrast, the **assignee** field is often empty: for **about half of all tickets**, no responsible person is recorded.
#
# 2. **Snapshot (more detailed subset of Issues)**
#    This dataset follows a similar pattern. Many entries are filled, but the **assignee is frequently missing**: for **roughly 35% of recorded processing steps**, no assignee is listed.
#
# 3. **Change History (log of edits to tickets)**
#    This dataset is almost complete. The “**new value after a change**” is missing in **less than 1%** of records. When values are hidden (“masked”), this happens **only for changes to the assignee field**, to protect privacy.
#
# 4. **Utterances (text messages/comments)**
#    The text data is **nearly complete**: **fewer than 0.1%** of utterances are missing. Some words or phrases are **masked** to protect the data provider’s privacy.
#
# 5. **Rated Sample (manually rated subset)**
#    Several ticket-identifying fields are missing in **about half of the cases** (e.g., **ID, issue number, project, reporter, type, priority, contributors**). The **turn assignee** is missing much less often (**under 3%**). Annotators added explanatory **notes** for the performance score in **around 64%** of cases.

# %% [markdown]
# # 10. Internal vs. external Tickets (for details, see FEATURES.md file)

# %%
dfi = dfi.copy()
dfi.columns = dfi.columns.str.strip()

proj = dfi["issue_proj"].astype("string").str.strip()

# Internal 
dfi["proj_type"]      = "internal"
dfi["country_code"]   = "internal"
dfi["client_product"] = "internal"

# External (masked country codes + a least 1 char)
dfi.loc[proj.str.match(r"^C\d{2}.+", na = False), "proj_type"]      = "external"
dfi.loc[proj.str.match(r"^C\d{2}.+", na = False), "country_code"]   = proj.loc[proj.str.match(r"^C\d{2}.+", na = False)].str.extract(r"^(C\d{2})", expand = False)
dfi.loc[proj.str.match(r"^C\d{2}.+", na = False), "client_product"] = proj.loc[proj.str.match(r"^C\d{2}.+", na = False)].str.extract(r"^C\d{2}(.+)$", expand = False)

# Missing 
missing = proj.isna()
dfi.loc[missing, ["proj_type", "country_code", "client_product"]] = "unknown"

# %% [markdown]
# # 11. Deciphering Timestamps

# %%
# Convert format
dfi["started"]               = pd.to_datetime(dfi["started"],               format = 'ISO8601')
dfi["ended"]                 = pd.to_datetime(dfi["ended"],                 format = 'ISO8601')
dfi["issue_created"]         = pd.to_datetime(dfi["issue_created"],         format = 'ISO8601')
dfi["last_change_date"]      = pd.to_datetime(dfi["last_change_date"],      format = 'ISO8601')
dfi["issue_resolution_date"] = pd.to_datetime(dfi["issue_resolution_date"], format = 'ISO8601')

dfs["started"]               = pd.to_datetime(dfs["started"],               format = 'ISO8601')
dfs["ended"]                 = pd.to_datetime(dfs["ended"],                 format = 'ISO8601')
dfs["issue_created"]         = pd.to_datetime(dfs["issue_created"],         format = 'ISO8601')
dfs["last_change_date"]      = pd.to_datetime(dfs["last_change_date"],      format = 'ISO8601')
dfs["issue_resolution_date"] = pd.to_datetime(dfs["issue_resolution_date"], format = 'ISO8601')

# %%
# Sanity check 1: Chronological order of ticket creation and resolution
print("Issues: Created after resolved:", int((dfi["issue_created"] > dfi["issue_resolution_date"]).sum()), "cases.")
print("Issues: Created after resolved:", int((dfi["issue_created"] > dfi["issue_resolution_date"]).sum()), "cases.")

# Sanity check 2: Chronological order of processing tickets
print("Snapshot: Started after ended:", int((dfs["started"] > dfs["ended"]).sum()), "cases.")
print("Snapshot: Started after ended:", int((dfs["started"] > dfs["ended"]).sum()), "cases.")
# Out:
# Issues: Created after resolved: 0 cases.
# Issues: Created after resolved: 0 cases.
# Snapshot: Started after ended: 0 cases.
# Snapshot: Started after ended: 0 cases.

# %% [markdown]
# Note: All good. ✓

# %% [markdown]
# # 12. Ability to Join Datasets

# %%
dfi_ids = set(dfi["id"].dropna().unique())

if "id" in dfs.columns:
    dfs_ids = dfs["id"].dropna().unique()
    pct = 100 * np.mean([x in dfi_ids for x in dfs_ids]) if len(dfs_ids) else np.nan
    print(f"Issue IDs in Snapshot found in Issue IDs: {pct:.2f}% of unique IDs\n")

if "issueid" in dfch.columns:
    dfch_ids = dfch["issueid"].dropna().unique()
    pct = 100 * np.mean([x in dfi_ids for x in dfch_ids]) if len(dfch_ids) else np.nan
    print(f"Issue ID in Change History found in Issue IDs: {pct:.2f}% of unique IDs\n")

if "issueid" in dfu.columns:
    dfu_ids = dfu["issueid"].dropna().unique()
    pct = 100 * np.mean([x in dfi_ids for x in dfu_ids]) if len(dfu_ids) else np.nan
    print(f"Issue IDs in Utterances found in Issue IDs: {pct:.2f}% of unique IDs\n")

if dfrate is not None and "id" in dfrate.columns:
    dfrate_ids = dfrate["id"].dropna().unique()
    pct = 100 * np.mean([x in dfi_ids for x in dfrate_ids]) if len(dfrate_ids) else np.nan
    print(f"Issue IDs in Performance Ratings found in Issue IDs: {pct:.2f}% of unique IDs\n")
# Out:
# Issue IDs in Snapshot found in Issue IDs: 100.00% of unique IDs
#
# Issue ID in Change History found in Issue IDs: 100.00% of unique IDs
#
# Issue IDs in Utterances found in Issue IDs: 100.00% of unique IDs
#
# Issue IDs in Performance Ratings found in Issue IDs: 100.00% of unique IDs

# %% [markdown]
# # 13. Correlations

# %% [markdown]
# ## a. Table: Numerical Variables

# %%
# Correlation matrix
corr_matrix_num = dfi_num.corr(method = "spearman")

# Convert correlation matrix to a long table
corr_table_num = corr_matrix_num.unstack().reset_index()
corr_table_num.columns = ["Variable 1", "Variable 2", "Correlation"]

# Each pair only once
corr_table_num = corr_table_num[corr_table_num["Variable 1"] < corr_table_num["Variable 2"]]

# Drop missing correlations
corr_table_num = corr_table_num.dropna(subset = ["Correlation"]) 

# Sort (large to small)
corr_table_num["Absolute Correlation"] = corr_table_num["Correlation"].abs()
corr_table_num = corr_table_num.sort_values("Absolute Correlation", ascending = False).drop(columns = "Absolute Correlation")

# More readable variable names
corr_table_num["Variable 1"] = corr_table_num["Variable 1"].map(num_var_read)
corr_table_num["Variable 2"] = corr_table_num["Variable 2"].map(num_var_read)
#corr_table_num["Var1_code"] = corr_table_num["Variable 1"]                    # original variable names - for reference
#corr_table_num["Var2_code"] = corr_table_num["Variable 2"]                    # original variable names - for reference

# Display
display(corr_table_num[(corr_table_num["Correlation"].abs() != 1.0)
                     & (corr_table_num["Correlation"].abs() != 0.0)].head(25).round(3))     # except for corr = 1.00 or 0.00
# Out:
#                               Variable 1                          Variable 2  \
# 455                           Total Time                    Status - Waiting
# 86                         Status - Open                          Total Time
# 465         Processing Steps until Final                       Status - Open
# 429         Status - Pending: Deployment                      Status - To Do
# 438         Status - Pending: Deployment                          Total Time
# 452                           Total Time                 Status - Validation
# 196          Status - Testing Monitoring                          Total Time
# 254                       Status - To Do                 Status - Validation
# 145  Status - Pending: Customer Approval  Status - Resolved under Monitoring
# 20                    Status - In Review                          Total Time
# 231                    Status - Reopened                      Status - To Do
# ...

# %% [markdown]
# ## b. Matrix: Numerical Variables

# %%
corr_plot_num = corr_matrix_num.rename(index = num_var_read, 
                                   columns = num_var_read)

plt.figure(figsize = (20, 15))
sns.heatmap(corr_plot_num, 
            annot      = True,      # values
            fmt        = ".2f",     # 2 digits
            cmap       = "coolwarm",   
            linewidths = .5,
            cbar_kws   = {"shrink": .8})
plt.xticks(rotation = 35, ha = "right")
plt.title("Correlation Matrix", fontsize = 16, fontweight = "bold")
plt.tight_layout()
plt.figtext(0.5, -0.02, "Note: Status in seconds.", ha = "center", fontsize = 10)
plt.show();

# %% [markdown]
# #### **1) Total time**
# **Correlated variables:** (1) Status: Waiting; (2) Status: Open <br>
# **Meaning:** Tickets that spend more time waiting or staying open end up taking much longer overall. <br>
# **Takeaway:** The biggest lever to reduce end-to-end time is to cut down idle time — e.g., waiting for inputs/approvals, dependencies, or unclear ownership.
#
# #### **2) Deployment status**
# **Correlated variables:** Total Time (and it moves together with To Do and Deployment) <br>
# **Meaning:** When work piles up before deployment, overall duration increases, i.e. this looks like a capacity constraint around releases. <br>
# **Takeaway:** Improving deployment throughput (more frequent releases, less batching, clearer readiness criteria, automation) is likely high impact.
#
# #### **3) Validation/review/testing stages add to total time**
# **Correlated variables:** Total Time and (1) Validation, (2/3) In Review / Under Review, (4) Testing Monitoring <br>
# **Meaning:** Tickets spending longer in quality-control steps tend to have longer cycle times. <br>
# **Takeaway:** Separate “necessary quality time” from “waiting inside quality steps.” If delays come from capacity/hand-offs, add reviewer bandwidth or streamline review/test workflows.
#
# #### **4) “To Do”**
# **Correlated variables:** Total Time and To Do (inverse relationships with some downstream statuses, e.g., validation/reopened paths). <br>
# **Meaning:** More time in “To Do” is a sign of front-of-process backlog and prioritization/capacity mismatch. <br>
# **Business takeaway:** Better triage, prioritization, and WIP limits can reduce queue time before work truly starts.
#
# #### **5) Processing steps - not the reason for longer total time**
# **Correlated variables:** Processing Steps until Final with (1) Total Time and (2) Status: Open (inverse relationships) <br>
# **Meaning:** The slow tickets are not slow because they go through many steps; they’re slow because they get stuck in a few statuses (especially Open/Waiting). <br>
# **Business takeaway:** Focus on flow and unblocking (ownership, next action, escalation rules) rather than mainly simplifying the workflow steps.
#
# #### **6) “either/or” outcomes**
# **Correlated variables:** Rejected vs Resolved; Closed with Done/Cancelled; review-related statuses with closure. <br>
# **Meaning:** These patterns mostly reflect the process structure (tickets typically follow one outcome path). <br>
# **Takeaway:** Useful for validating the workflow logic.

# %% [markdown]
# ## c. Table: Categorical/Dummy Variables

# %%
# Correlation matrix
corr_matrix_dum = dummy_col.corr(method = "spearman")

# Convert correlation matrix to a long table
corr_table_dum = (corr_matrix_dum.unstack()
                                 .reset_index()
                                 .rename(columns = {"level_0" : "Variable 1", 
                                                    "level_1" : "Variable 2", 
                                                    0         : "Correlation"}))

# Each pair only once
corr_table_dum = corr_table_dum[corr_table_dum["Variable 1"] < corr_table_dum["Variable 2"]]

# Drop missing correlations
corr_table_dum = corr_table_dum.dropna(subset = ["Correlation"])

# Sort (large to small)
corr_table_dum["Absolute Correlation"] = corr_table_dum["Correlation"].abs()
corr_table_dum = corr_table_dum.sort_values("Absolute Correlation", ascending = False).drop(columns = "Absolute Correlation")

# More readable variable names
def dummy_col_value(name: str) -> str:
    if "_" in name:
        prefix, category = name.split("_", 1)
        prefix_label     = cat_var_read.get(prefix, prefix)
        category         = category.replace("_", " ").title()
        return f"{prefix_label}: {category}"
    return cat_var_read.get(name, name)

corr_table_dum["Variable 1"] = corr_table_dum["Variable 1"].map(dummy_col_value)
corr_table_dum["Variable 2"] = corr_table_dum["Variable 2"].map(dummy_col_value)
#corr_table_dum["Var1_code"] = corr_table_dum["Variable 1"]                    # original variable names - for reference
#corr_table_dum["Var2_code"] = corr_table_dum["Variable 2"]                    # original variable names - for reference

# Display
display(corr_table_dum[(corr_table_dum["Correlation"].abs() != 1.0)
                     & (corr_table_dum["Correlation"].abs() != 0.0)].head(25).round(3))     # except for corr = 1.00 or 0.00
# Out:
#                          Variable 1                     Variable 2  \
# 2761           issue: Status Closed             issue: Status Done
# 1195                 wf: Total Time                    wf: Waiting
# 197                        wf: Open                 wf: Total Time
# 2522         issue: Resolution Done     issue: Resolution Won'T Do
# 2401         issue: Priority Medium        issue: Priority Unknown
# 1242              processing: Steps                       wf: Open
# 1132         wf: Pending Deployment                      wf: To Do
# 1141         wf: Pending Deployment                 wf: Total Time
# 2422        issue: Priority Unknown                       wf: Open
# 2803             issue: Status Done              issue: Type Story
# 1192                 wf: Total Time                 wf: Validation
# 2744           issue: Status Closed              issue: Type Story
# 492          wf: Testing Monitoring                 wf: Total Time
# ...

# %% [markdown]
# ## d. Matrix: Categorical/Dummy Variables

# %%
corr_plot_dum = corr_matrix_dum.rename(index = dummy_col_value, 
                                       columns = dummy_col_value)

plt.figure(figsize = (40, 30))
sns.heatmap(corr_plot_dum, 
            annot      = np.where(np.triu(np.ones_like(corr_plot_dum.to_numpy(), dtype = bool)) # just large(r) correlations
                                  | corr_plot_dum.isna().to_numpy()
                                  | (corr_plot_dum.abs().to_numpy() < 0.30),
                                  "",
                                  np.char.mod("%.2f", corr_plot_dum.to_numpy())),
            fmt        = "",
            mask       = np.triu(np.ones_like(corr_plot_dum, dtype = bool)),                     # just one triangle
            cmap       = "coolwarm",   
            linewidths = .5,
            cbar_kws   = {"shrink": .7})
plt.xticks(rotation = 45, ha = "right", fontsize = 12)
plt.yticks(rotation = 0, fontsize = 12)
plt.title("Correlation Matrix (p > .03)", fontsize = 16, fontweight = "bold")
plt.tight_layout()
plt.figtext(0.5, -0.02, "Note: Dummy variables are 0/1 indicators.", ha = "center", fontsize = 10)
plt.show();

# %% [markdown]
# #### **1) “either/or” outcomes**
# **Examples:**(1) Issue: Status Closed vs. Done, (2) Resolution: Done vs. Won’t Do, or (3) Priority Medium vs. Unknown <br>
# **Meaning:** A ticket can’t realistically be in two different statuses/resolutions/priorities at once, so these move in opposite directions by design.<br>
# **Business takeaway:** Treat them more as sanity checks that encoding is consistent — not as drivers of performance.
#
# #### **2) Risky “Unknown” priority: longer and more “Open” work**
# **Correlated variables:** Priority Unknown and (1) Open Workflow (2) Total Time of Workflow<br>
# **Meaning:** Tickets with unclear/unknown priority tend to stay open longer and have longer overall cycle times.<br>
# **Business takeaway:** Improve intake quality: require priority assignment, add triage rules, and prevent “Unknown” from reaching the backlog.
#
# #### **3) Type Story**
# **Correlated variables:** Issue Type Story and (1) Issue: Status Done (positive) / (2) Issue: Status Closed (negative)<br>
# **Meaning:** Stories are more often marked “Done” rather than “Closed” (or follow a different workflow path/end-state).<br>
# **Business takeaway:** When comparing performance across tickets, separate by type (Story vs others) — otherwise end-state and KPI comparisons can be misleading.
#
# #### **4) Key workflow time drivers**
# **Correlated variables:** Total Time of Workflow and (1) Waiting, (2) Open, (3) Validation, (4) Testing Monitoring; Pending Deployment of Workflow and (1) To Do, (2) Total Time<br>
# **Meaning:** Longer tickets are still primarily explained by time stuck in “Waiting/Open” and by a “Pending Deployment” queue effect.<br>
# **Business takeaway:** Same operational levers: reduce waiting/hand-offs, manage WIP, and improve deployment throughput.
#
# #### **5) Process steps vs time:**
# **Correlated variables:** Processing Steps and (1) Workflow: Open (negative), (2) Total Time of Workflow (negative)<br>
# **Meaning:** Long cycle time is associated with fewer transitions but longer time sitting in a few states.<br>
# **Business takeaway:** Focus on unblocking and ownership/SLAs, not just simplifying the workflow.
#
# #### **6) Outcome path structure**
# **Correlated variables:** Workflow: Rejected and Resolved (negative), Workflow: Approved and Resolved Under Monitoring (negative)<br>
# **Meaning:** These represent different outcome paths/states rather than independent drivers.<br>
# **Business takeaway:** Useful for validating the process; not the first place to optimize lead time.

# %% [markdown]
# # 14. Outliers

# %% [markdown]
# ## a. Function: Calculating Outliers

# %%
def calculate_outliers(series): 

    s = series.dropna()
    if s.empty:
        return pd.Series({"N": 0,
                          "Number of Outliers": 0,
                          "Lower Bound": np.nan,
                          "Upper Bound": np.nan})

    q1 = s.quantile(0.25)
    q3 = s.quantile(0.75)
    iqr = q3 - q1
    lower = q1 - 1.5 * iqr
    upper = q3 + 1.5 * iqr

    n_outliers = ((s < lower) | (s > upper)).sum()

    return pd.Series({
        "N": int(s.shape[0]),
        "Number of Outliers": int(n_outliers),
        "Lower Bound": float(lower),
        "Upper Bound": float(upper)
    })

# %% [markdown]
# ## b. Numeric Variables

# %%
dfi_num_outliers = (dfi_num.apply(calculate_outliers).T
                           .round(4)
                           .reset_index()
                           .rename(columns = {"index": "Column"})
                           .sort_values("Column")
                           .reset_index(drop = True))

dfi_num_outliers_col = (dfi_num_outliers.sort_values("Number of Outliers", ascending = True)["Column"].tolist())

dfi_num_outliers_col_long = ((dfi_num[dfi_num_outliers_col] / 86400)  # convert seconds to days
                                     .melt(var_name = "Variable", value_name = "Days")
                                     .dropna())

boxenplot = dfi_num_outliers_col_long.copy()
boxenplot["Variable"] = boxenplot["Variable"].replace(num_var_read)

plt.figure(figsize = (12, 7))
sns.boxenplot(data = boxenplot, 
              y = "Variable", 
              x = "Days", 
              orient = "h",
              color = "skyblue")
plt.xlim(0, dfi_num_outliers_col_long["Days"].quantile(0.99))
plt.xlabel("Days (zoomed to 99th percentile)")
plt.title("Distributions")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Takeaway:
#
# 1. The distributions are highly right-skewed: most tickets spend very little time in most statuses (good!) but a small subset shows extremely long durations (long tail), which likely drives many of the “slow process” perceptions.<br>
# 2. The widest spreads are in Total Time and Status – Open, suggesting that overall cycle time is mainly determined by how long tickets remain open rather than by many intermediate steps.<br>
# 3. Status – Done also shows very large values for some tickets, which can indicate lingering end-state handling (e.g., items staying “done” for a long time before being formally closed).<br>
# 4. Deployment-related stages (especially Pending: Deployment) show noticeable tail behavior, consistent with occasional queueing before release.<br>
# 5. Overall, the plot points to a “few stuck tickets” problem: improving aging/blocked-ticket handling and queue management will likely reduce cycle time more than optimizing the typical fast path.

# %% [markdown]
# # 15. Graphs

# %% [markdown]
# ## a. Overview over Issue Types

# %%
counts = dfs["issue_type"].astype("string").fillna("Unknown").value_counts()

plt.figure(figsize = (10, 5))
sns.barplot(x = counts.index, 
            y = counts.values / 1000,
            color = "skyblue")
plt.title("Overview over Issue Types")
plt.xlabel("Issue Type", fontsize = 9)
plt.ylabel("Ticket Count in Thousands", fontsize = 9)
plt.xticks(rotation = 45, ha = "center", fontsize = 9)
plt.tight_layout()
plt.show();

# %% [markdown]
# #### Takeaway
# Most issues (> 60%) are of the type "ticket". Frequently used are also "service", "story", "subtask", and "HD service" (5-10%).

# %% [markdown]
# ## b. Issue Types over Time

# %%
groupby_m = (dfs.groupby([pd.Grouper(key = "started", freq = "ME"), "issue_type"])
                .size()                          # counts rows
                .unstack(fill_value = 0))        # columns = issue_type

groupby_m.plot(figsize = (15, 9), style = ".-").legend(loc = "upper left", fontsize = 12)
plt.title("Temporal Development of Issue Types", fontsize = 14)
plt.xlabel("Issue Type", fontsize = 12)
plt.ylabel("Ticket Count in Thousands", fontsize = 12)
plt.xticks(rotation = 45, ha = "center", fontsize = 12)
plt.yticks(fontsize = 12)
plt.tight_layout()
plt.show();

# %% [markdown]
# #### Takeaway:
#
# Until 2015, issues were classified almost exclusively as "Ticket" or "Bug", so earlier years are not directly comparable to later ones in terms of type distribution. <br>
# From 2015 onward, additional types were introduced; notably, "Story" appears mainly between 2015 and 2018, suggesting either a temporary classification practice or a specific initiative/project phase. <br>
# Over the full period, "Ticket" is the only type that shows a steady long-term increase, indicating it became the dominant and consistently used category. However, the sharp drop in Ticket in 2023 likely reflects a process or tooling change (e.g., due to reclassification into newer types, changes in intake/reporting, migration effects) rather than an actual collapse in workload.

# %% [markdown]
# ## c. Time per Workflow Step

# %%
mean_days = (dfi[
    [c for c in dfi_num.columns if c.startswith("wf_")]
    ].mean() / 86400).dropna().sort_values(ascending = False).rename(index = num_var_read)

plt.figure(figsize = (15, 8))
bars = plt.barh(mean_days.index,
                mean_days.values,
                color = 'skyblue')

plt.title('Average Time per Workflow Status', fontsize = 14)
plt.xlabel('Days per Workflow Status', fontsize = 12)
plt.ylabel('Status', fontsize = 12)
plt.gca().invert_yaxis()
plt.grid(axis = 'x', linestyle = '--', alpha = 0.7)

for i, v in enumerate(mean_days):
    plt.text(v + mean_days.max() * 0.01, i, f'{v:.2f}', va = "center")

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Takeaway:
#
# 1. On average, tickets spend by far the most time in **Open**, and this almost fully explains the high **Total Time** — meaning overall cycle time is primarily driven by how long items remain open rather than by many downstream steps. <br>
# 2. The only other status with a clearly elevated average is **Done**, which suggests tickets often linger after work is “finished” (e.g., delayed closure/administrative wrap-up). <br>
# 3. All remaining workflow stages have comparatively small average durations (mostly in the tens of days or less), including **Pending: Deployment** and **To Do**, which still stand out as the biggest “mid-process” time buckets.

# %% [markdown]
# ## d. Time per Project Type

# %%
proj = dfi["proj_type"].astype("string").str.strip().fillna("Unknown")
days = pd.to_numeric(dfi["wf_total_time"], errors = "coerce") / 86400
mask = days.notna() & proj.notna()

tmp = pd.DataFrame({"proj_type"          : proj[mask],
                    "wf_total_time_days" : days[mask]})

sns.set_style("whitegrid")
plt.figure(figsize = (10, 5))

sns.boxplot(data = tmp, 
            x = "proj_type", 
            y = "wf_total_time_days", 
            showfliers = False,
            color = "skyblue")

sns.stripplot(data = tmp, 
              x = "proj_type", 
              y = "wf_total_time_days", 
              color = "black", 
              alpha = 0.25, 
              size = 2, 
              jitter = 0.25)

plt.title('Distribution of Total Workflow Time by Project Type (in Days)')
plt.xlabel('Project Type')
plt.ylabel('Total Workflow Time (Days)')
plt.tight_layout()
plt.show();

# %% [markdown]
# #### Takeaway:
#
# 1. **External projects** have longer total workflow times on average and greater variability than internal projects. Thus, they are more prone to extended delays and inconsistent turnaround.
# 2. **Both types** include many fast/short tickets, however, the external group contains a large mass of cases with very long durations.

# %% [markdown]
# ## e. Issue Priority

# %%
if "issue_priority" in dfi.columns:
    priority = (dfi["issue_priority"]
                .astype("string")
                .str.strip()
                .fillna("Unknown")
                .str.title()
                .replace({"Unkown": "Unknown"}))
    order = ["Blocker", "Highest", "High", "Medium", "Low", "Lowest", "Unknown"]
    pct = (priority.value_counts().reindex(order, fill_value = 0)) / (priority.value_counts().reindex(order, fill_value = 0)).sum() * 100
    
    plt.figure()
    plt.bar(pct.index,
            pct.values,
            color = "skyblue") 
    plt.title("Priorities of Issues")
    plt.xticks(rotation = 45, ha = "right") 
    plt.xlabel("Issue Priority")
    plt.ylabel("Percentage")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### Takeaway:
#
# 1. Around half of all issues have no priority assigned, indicating that prioritization is either optional in practice or not consistently applied. <br>
# 2. Among the issues that do have a priority, “Medium” is the most common rating, suggesting a tendency to default to the middle category rather than differentiating urgency.

# %% [markdown]
# ## f. Processing Time

# %%
if "wf_total_time" in dfi.columns:
    time = (dfi["wf_total_time"]/2592000).dropna()

    if len(time) > 0:
        plt.figure()
        plt.hist(time, 
                 bins = 20,
                 color = "skyblue")
        plt.title("Total Processing Time of Tickets (in Months)")
        plt.xlabel("Months")
        plt.ylabel("Count")
        plt.tight_layout()
        plt.show()

# %% [markdown]
# #### Takeaway:
#
# 1. Most tickets are completed within a short time window, creating a large spike at the low end of the x-axis. <br>
# 2. At the same time, there is a long tail reaching well beyond multiple years, meaning a small subset of tickets stays in the system for extremely long periods. This implies that average processing time is likely inflated by a minority of very old/stuck tickets, so medians and percentiles are more representative than the mean. <br>
# 3. It can be useful to identify and manage these aging tickets.
